# %% [markdown]
# ## Model features
#
# - fixed length timeseries informed by d_per_de ~ 4
#
# - One classification for an entire small inner subset of each timeseries segment
#
# - Optuna integration
#
# - Comparison with best possible majority-rule classification of the inner segment

# %%
import sys
import datetime as dt
import h5py
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
import optuna
from optuna.integration import TFKerasPruningCallback
from optuna.trial import TrialState
import matplotlib.pyplot as plt
from scipy.stats import mode

# get functions from other notebooks
# %run /tigress/kendrab/analysis-notebooks/loss_fns.ipynb
# %run /tigress/kendrab/analysis-notebooks/metrics.ipynb
# %run /tigress/kendrab/analysis-notebooks/preproc_utils.ipynb

# %% [markdown]
# ### Optimize via optuna

# %%
def objective(trial):
    keras.backend.clear_session()
    
    """ Assemble a model"""
    #######################
    model_name = "eta"
    # hyperparameters
    learning_rate = trial.suggest_float("learning_rate", 1e-3, 1e-1, log=True)
    filters = trial.suggest_categorical("filters", [16,32])
    kernel_size = 3
    pool_size = 2
    padding_length = trial.suggest_int("padding_length", 10, 30)  
                                       # amount of data on each side of each segment for additional info
    stride = trial.suggest_int("stride", 1, 7)  # size (and therefore spacing) of each segment
    input_length = stride + 2*padding_length
    mask_value = int(-10.0)
    epochs = 5
    thinning_factor = [.5, None]
    hyperparams = {'learning_rate':learning_rate, 'filters':filters, 'kernel_size':kernel_size, 'pool_size':pool_size,
                  'padding_length':padding_length, 'stride':stride, 'input_length':input_length, 'epochs':epochs,
                   'thinning_factor':thinning_factor}

    # input
    bx_input = keras.Input(shape=(input_length,1), name="bx") 
    by_input = keras.Input(shape=(input_length,1), name="by") 
    bz_input = keras.Input(shape=(input_length,1), name="bz") 
    jy_input = keras.Input(shape=(input_length,1), name="jy") 
    vz_input = keras.Input(shape=(input_length,1), name="vz") 

    # convolve and pool separately
    bx_conv = keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, padding='valid')(bx_input)
    by_conv = keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, padding='valid')(by_input)
    bz_conv = keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, padding='valid')(bz_input)
    jy_conv = keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, padding='valid')(jy_input)
    vz_conv = keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, padding='valid')(vz_input)

    bx_pool = keras.layers.MaxPooling1D(pool_size=pool_size)(bx_conv)
    by_pool = keras.layers.MaxPooling1D(pool_size=pool_size)(by_conv)
    bz_pool = keras.layers.MaxPooling1D(pool_size=pool_size)(bz_conv)
    jy_pool = keras.layers.MaxPooling1D(pool_size=pool_size)(jy_conv)
    vz_pool = keras.layers.MaxPooling1D(pool_size=pool_size)(vz_conv)

    # merge the layers together
    avg = keras.layers.Average()([bx_pool, by_pool, bz_pool, jy_pool, vz_pool])
    # convolve and pool
    avg_conv = keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, padding='valid')(avg)
    avg_pool = keras.layers.MaxPooling1D(pool_size=pool_size)(avg_conv)


    # use dense layer to output
    flat_pool = keras.layers.Flatten()(avg_pool)
    condensed_logits = keras.layers.Dense(2, activation='relu')(flat_pool)  # one prediction for the entire stride
    condensed_probs = keras.layers.Softmax()(condensed_logits)
    reshaped_logits = keras.layers.Reshape((1, 2))(condensed_logits)
    logits = tf.repeat(reshaped_logits, stride, axis=1) # same probability for each point in the inner segment
    probs = keras.layers.Softmax()(logits)

    # throw together the model
    model = keras.Model(
        inputs=[bx_input, by_input, bz_input, jy_input, vz_input],
        outputs=[probs])

    # show the model
    model.summary()
    keras.utils.plot_model(model, "/scratch/gpfs/kendrab/model_"+model_name+".png", show_shapes=True)


    """Get 1d sampling"""
    #####################
    readpaths = ['/tigress/kendrab/03082021/'+"1000samples_idx22_bxbybzjyvz.hdf5",
                 '/tigress/kendrab/03082021/'+"1000samples_idx18_bxbybzjyvz.hdf5",
                 '/tigress/kendrab/03082021/'+"1000samples_idx15_bxbybzjyvz.hdf5"]

    idx_list = []  # to keep track of which file what sample came from
    s_list = []
    bx_list = []
    by_list = []
    bz_list = []
    jy_list = []
    vz_list = []
    x0_list = []
    x1_list = []
    topo_list = []

    for idx, filepath in enumerate(readpaths):
        file = h5py.File(filepath, 'r')
        idx_list += [np.array([idx for i in bx]) for bx in file['bx_smooth'][:]]  # check this structure!!!
        s_list += list(file['s'][:])
        bx_list += list(file['bx_smooth'][:])
        by_list += list(file['by'][:])
        bz_list += list(file['bz_smooth'][:])
        jy_list += list(file['jy'][:])
        vz_list += list(file['vz'][:]) 
        x0_list += list(file['x0'][:])
        x1_list += list(file['x1'][:])
        topo_list_tmp = list(file['topo'][:])
        for i in range(len(topo_list_tmp)):  # I tried to vectorize this but I didn't get it to work
            topo_list_tmp[i] = topo_list_tmp[i] % 2  # cat 0,2 are not plasmoids, cat 1,3 are
            topo_list_tmp[i] = keras.utils.to_categorical(topo_list_tmp[i], num_classes=2)
        topo_list += topo_list_tmp
        file.close()


    """ Preprocess data"""
    ######################
    idx_segs = batch_unpadded_subsects(idx_list, padding_length, stride)
    s_segs = batch_subsects(s_list, input_length, stride).reshape(-1, input_length, 1)
    bx_segs = batch_subsects(bx_list, input_length, stride).reshape(-1, input_length, 1)
    by_segs = batch_subsects(by_list, input_length, stride).reshape(-1, input_length, 1)
    bz_segs = batch_subsects(bz_list, input_length, stride).reshape(-1, input_length, 1)
    jy_segs = batch_subsects(jy_list, input_length, stride).reshape(-1, input_length, 1)
    vz_segs = batch_subsects(vz_list, input_length, stride).reshape(-1, input_length, 1)
    x0_segs = batch_unpadded_subsects(x0_list, padding_length, stride)
    x1_segs = batch_unpadded_subsects(x1_list, padding_length, stride)
    topo_segs = batch_unpadded_subsects(topo_list, padding_length, stride)
    # find the mode of each topo segment for metrics later
    topo_int_segs = np.argmax(topo_segs, axis=-1)  # back to integer classes
    modes_tmp = mode(topo_int_segs, axis=1)[0].reshape(-1,1,1) # most common class for each segment, broadcastable 
    # put it back in the same shape and style as topo_segs
    topo_modes_segs = keras.utils.to_categorical(np.repeat(modes_tmp, stride, axis=1),  num_classes=2)
    # s p l i t TODO: add validation set?
    (idx_train, idx_test, s_train, s_test, bx_train, bx_test, by_train, by_test, bz_train, bz_test, jy_train, jy_test, vz_train, vz_test, 
         x0_train, x0_test, x1_train, x1_test, topo_train, topo_test, topo_modes_train, topo_modes_test) = \
                           train_test_split(idx_segs, s_segs, bx_segs, by_segs, bz_segs, jy_segs, vz_segs,
                                            x0_segs, x1_segs, topo_segs, topo_modes_segs)
    # try to do some rebalancing in the training set
    # model is struggling on plasmoids, which are underrepresented
    [idx_train, s_train, bx_train, by_train, bz_train, jy_train, vz_train, x0_train, x1_train, topo_modes_train], \
        topo_train = rebalance_ctrl_group([idx_train, s_train, bx_train, by_train, bz_train, jy_train, vz_train, 
                                           x0_train, x1_train, topo_modes_train], topo_train, null_label=[1,0], 
                                          thinning_factor = thinning_factor[0])
    [idx_test, s_test, bx_test, by_test, bz_test, jy_test, vz_test, x0_test, x1_test, topo_modes_test], \
        topo_test = rebalance_ctrl_group([idx_test, s_test, bx_test, by_test, bz_test, jy_test, vz_test, x0_test,
                                         x1_test, topo_modes_test], topo_test, null_label=[1,0],
                                         thinning_factor = thinning_factor[0])
    

    """ Compile and train model """
    ###############################
    weights = {i:np.sum(topo_train)/np.sum(topo_train[...,i]) for i in range(topo_train.shape[-1])}
    opt = keras.optimizers.Adam(learning_rate=learning_rate)
    loss_fn = keras.losses.CategoricalCrossentropy()
    loss = LossPerPt(loss_fn=loss_fn, class_weights=weights)
    metrics = [keras.metrics.BinaryAccuracy(name='acc'), keras.metrics.AUC(name='prc', curve='PR'), keras.metrics.Precision(class_id=1), avg_metric(keras.metrics.Precision)]  # loss_fn keyword left default
    pruning_metric = 'precision'


    model.compile(optimizer=opt, loss=loss, metrics=metrics,
                 run_eagerly = True)  # run eagerly to get .numpy() method

    model.fit(x={'bx': bx_train, 'by': by_train, 'bz': bz_train, 'jy': jy_train, 'vz': vz_train},
              y = topo_train, epochs=epochs, callbacks=[TFKerasPruningCallback(trial, pruning_metric)])
    score = model.evaluate(x={'bx': bx_test, 'by': by_test, 'bz': bz_test, 'jy': jy_test, 'vz': vz_test}, y=topo_test, verbose=0,
                          return_dict=True)
    score_agst_mode = model.evaluate(x={'bx': bx_test, 'by': by_test, 'bz': bz_test, 'jy': jy_test, 'vz': vz_test}, y=topo_modes_test, verbose=0,
                      return_dict=True)
    print(f"Compared against section modes: {score_agst_mode}")
    print("Section mode performance against full sections: ")
    for metric in metrics:
        print(f"{metric.name} : {metric(topo_test, topo_modes_test)}")
    return score[pruning_metric]

# %%
study = optuna.create_study(direction="maximize", pruner=optuna.pruners.MedianPruner(n_startup_trials=2))
study.optimize(objective, n_trials=20, timeout=3600)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])
print("Study statistics: ")
print("  Number of finished trials: ", len(study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))
print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

ax = optuna.visualization.matplotlib.plot_param_importances(study)
plt.show()
# Out:
# [I 2022-05-04 10:10:48,639] A new study created in memory with name: no-name-112a54e3-6363-46a0-a29e-88328a385fa9
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# bx (InputLayer)                 [(None, 66, 1)]      0
# __________________________________________________________________________________________________
# by (InputLayer)                 [(None, 66, 1)]      0
# __________________________________________________________________________________________________
# bz (InputLayer)                 [(None, 66, 1)]      0
# __________________________________________________________________________________________________
# jy (InputLayer)                 [(None, 66, 1)]      0
# __________________________________________________________________________________________________
# vz (InputLayer)                 [(None, 66, 1)]      0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 64, 16)       64          bx[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 64, 16)       64          by[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 64, 16)       64          bz[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 64, 16)       64          jy[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 64, 16)       64          vz[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 32, 16)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 32, 16)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 32, 16)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 32, 16)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 32, 16)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# average (Average)               (None, 32, 16)       0           max_pooling1d[0][0]
#                                                                  max_pooling1d_1[0][0]
#                                                                  max_pooling1d_2[0][0]
#                                                                  max_pooling1d_3[0][0]
#                                                                  max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 30, 16)       784         average[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 15, 16)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 240)          0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            482         flatten[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 2)         0           dense[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape (TensorFlowOp [(3,)]               0           reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [()]                 0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [()]                 0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims (TensorF [(None, 1, 1, 2)]    0           reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(1,)]               0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat/values_1 (Te [(1,)]               0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_2 (Te [(1,)]               0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Tile (TensorFlowOpL [(None, 1, 6, 2)]    0           tf_op_layer_ExpandDims[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(3,)]               0           tf_op_layer_strided_slice[0][0]
#                                                                  tf_op_layer_concat/values_1[0][0]
#                                                                  tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape (TensorFlow [(None, None, 2)]    0           tf_op_layer_Tile[0][0]
#                                                                  tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# softmax_1 (Softmax)             (None, None, 2)      0           tf_op_layer_Reshape[0][0]
# ==================================================================================================
# Total params: 1,586
# Trainable params: 1,586
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# Total batch: 157868
# Number of null samples: 156072
# Number of non-null samples: 1796
# With thinning factor 0.5 will remove 78036 null samples
# Total batch: 52623
# Number of null samples: 52051
# Number of non-null samples: 572
# With thinning factor 0.5 will remove 26025 null samples
# Epoch 1/5
# 2495/2495 [==============================] - 166s 66ms/step - loss: 1.3931 - acc: 0.5017 - prc: 0.5068 - precision: 0.0162 - Precision_avg: 0.0094
# Epoch 2/5
# 2495/2495 [==============================] - 163s 65ms/step - loss: 1.3863 - acc: 0.5000 - prc: 0.5000 - precision: 0.0000e+00 - Precision_avg: 0.0000e+00
# Epoch 3/5
# 2495/2495 [==============================] - 164s 66ms/step - loss: 1.3863 - acc: 0.5000 - prc: 0.5000 - precision: 0.0000e+00 - Precision_avg: 0.0000e+00
# Epoch 4/5
# 2495/2495 [==============================] - 167s 67ms/step - loss: 1.3863 - acc: 0.5000 - prc: 0.5000 - precision: 0.0000e+00 - Precision_avg: 0.0000e+00
# Epoch 5/5
# 2495/2495 [==============================] - 172s 69ms/step - loss: 1.3863 - acc: 0.5000 - prc: 0.5000 - precision: 0.0000e+00 - Precision_avg: 0.0000e+00
# Compared against section modes: {'loss': 1.3637028932571411, 'acc': 0.5, 'prc': 0.5, 'precision': 0.0, 'Precision_avg': 0.0}
# Section mode performance against full sections:
# acc : 0.7496083378791809
# prc : 0.8865537643432617
# precision : 0.9850746393203735
# Precision_avg : 0.992291122674942
# [I 2022-05-04 10:26:18,103] Trial 0 finished with value: 0.0 and parameters: {'learning_rate': 0.038237236791230686, 'filters': 16, 'padding_length': 30, 'stride': 6}. Best is trial 0 with value: 0.0.
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# bx (InputLayer)                 [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# by (InputLayer)                 [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# bz (InputLayer)                 [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# jy (InputLayer)                 [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# vz (InputLayer)                 [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 55, 16)       64          bx[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 55, 16)       64          by[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 55, 16)       64          bz[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 55, 16)       64          jy[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 55, 16)       64          vz[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 27, 16)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 27, 16)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 27, 16)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 27, 16)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 27, 16)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# average (Average)               (None, 27, 16)       0           max_pooling1d[0][0]
#                                                                  max_pooling1d_1[0][0]
#                                                                  max_pooling1d_2[0][0]
#                                                                  max_pooling1d_3[0][0]
#                                                                  max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 25, 16)       784         average[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 12, 16)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 192)          0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            386         flatten[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 2)         0           dense[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape (TensorFlowOp [(3,)]               0           reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [()]                 0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [()]                 0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims (TensorF [(None, 1, 1, 2)]    0           reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(1,)]               0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat/values_1 (Te [(1,)]               0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_2 (Te [(1,)]               0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Tile (TensorFlowOpL [(None, 1, 7, 2)]    0           tf_op_layer_ExpandDims[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(3,)]               0           tf_op_layer_strided_slice[0][0]
#                                                                  tf_op_layer_concat/values_1[0][0]
#                                                                  tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape (TensorFlow [(None, None, 2)]    0           tf_op_layer_Tile[0][0]
#                                                                  tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# softmax_1 (Softmax)             (None, None, 2)      0           tf_op_layer_Reshape[0][0]
# ==================================================================================================
# Total params: 1,490
# Trainable params: 1,490
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# Total batch: 138369
# Number of null samples: 136788
# Number of non-null samples: 1581
# With thinning factor 0.5 will remove 68394 null samples
# Total batch: 46123
# Number of null samples: 45615
# Number of non-null samples: 508
# With thinning factor 0.5 will remove 22807 null samples
# Epoch 1/5
# 2187/2187 [==============================] - 166s 76ms/step - loss: 1.1760 - acc: 0.6730 - prc: 0.8082 - precision: 0.0000e+00 - Precision_avg: 0.4845
# Epoch 2/5
# 2187/2187 [==============================] - 160s 73ms/step - loss: 1.1453 - acc: 0.6806 - prc: 0.8171 - precision: 0.0000e+00 - Precision_avg: 0.4997
# Epoch 3/5
# 2187/2187 [==============================] - 133s 61ms/step - loss: 1.1471 - acc: 0.6851 - prc: 0.8222 - precision: 0.0000e+00 - Precision_avg: 0.4999
# Epoch 4/5
# 2187/2187 [==============================] - 135s 62ms/step - loss: 1.1259 - acc: 0.6923 - prc: 0.8302 - precision: 0.0268 - Precision_avg: 0.5000
# Epoch 5/5
# 2187/2187 [==============================] - 145s 66ms/step - loss: 1.1269 - acc: 0.6890 - prc: 0.8266 - precision: 0.0000e+00 - Precision_avg: 0.4999
# Compared against section modes: {'loss': 1.0825304985046387, 'acc': 0.6955953240394592, 'prc': 0.8338846564292908, 'precision': 0.0, 'Precision_avg': 0.4999571442604065}
# Section mode performance against full sections:
# acc : 0.8472400903701782
# [I 2022-05-04 10:40:04,085] Trial 1 finished with value: 0.0 and parameters: {'learning_rate': 0.004245040033804305, 'filters': 16, 'padding_length': 25, 'stride': 7}. Best is trial 0 with value: 0.0.
# prc : 0.9561790227890015
# precision : 0.9678416848182678
# Precision_avg : 0.9857373535633087
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# bx (InputLayer)                 [(None, 31, 1)]      0
# __________________________________________________________________________________________________
# by (InputLayer)                 [(None, 31, 1)]      0
# __________________________________________________________________________________________________
# bz (InputLayer)                 [(None, 31, 1)]      0
# __________________________________________________________________________________________________
# jy (InputLayer)                 [(None, 31, 1)]      0
# __________________________________________________________________________________________________
# vz (InputLayer)                 [(None, 31, 1)]      0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 29, 16)       64          bx[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 29, 16)       64          by[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 29, 16)       64          bz[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 29, 16)       64          jy[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 29, 16)       64          vz[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 14, 16)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 14, 16)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 14, 16)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 14, 16)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 14, 16)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# average (Average)               (None, 14, 16)       0           max_pooling1d[0][0]
#                                                                  max_pooling1d_1[0][0]
#                                                                  max_pooling1d_2[0][0]
#                                                                  max_pooling1d_3[0][0]
#                                                                  max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 12, 16)       784         average[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 6, 16)        0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 96)           0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            194         flatten[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 2)         0           dense[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape (TensorFlowOp [(3,)]               0           reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [()]                 0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [()]                 0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims (TensorF [(None, 1, 1, 2)]    0           reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(1,)]               0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat/values_1 (Te [(1,)]               0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_2 (Te [(1,)]               0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Tile (TensorFlowOpL [(None, 1, 7, 2)]    0           tf_op_layer_ExpandDims[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(3,)]               0           tf_op_layer_strided_slice[0][0]
#                                                                  tf_op_layer_concat/values_1[0][0]
#                                                                  tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape (TensorFlow [(None, None, 2)]    0           tf_op_layer_Tile[0][0]
#                                                                  tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# softmax_1 (Softmax)             (None, None, 2)      0           tf_op_layer_Reshape[0][0]
# ==================================================================================================
# Total params: 1,298
# Trainable params: 1,298
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# Total batch: 146747
# Number of null samples: 145105
# Number of non-null samples: 1642
# With thinning factor 0.5 will remove 72552 null samples
# Total batch: 48916
# Number of null samples: 48386
# Number of non-null samples: 530
# With thinning factor 0.5 will remove 24193 null samples
# Epoch 1/5
# 2319/2319 [==============================] - ETA: 0s - loss: 1.3970 - acc: 0.5013 - prc: 0.5056 - precision: 0.0000e+00 - Precision_avg: 0.0053
# [I 2022-05-04 10:42:59,796] Trial 2 pruned. Trial was pruned at epoch 0.
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# bx (InputLayer)                 [(None, 55, 1)]      0
# __________________________________________________________________________________________________
# by (InputLayer)                 [(None, 55, 1)]      0
# __________________________________________________________________________________________________
# bz (InputLayer)                 [(None, 55, 1)]      0
# __________________________________________________________________________________________________
# jy (InputLayer)                 [(None, 55, 1)]      0
# __________________________________________________________________________________________________
# vz (InputLayer)                 [(None, 55, 1)]      0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 53, 32)       128         bx[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 53, 32)       128         by[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 53, 32)       128         bz[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 53, 32)       128         jy[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 53, 32)       128         vz[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 26, 32)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 26, 32)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 26, 32)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 26, 32)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 26, 32)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# average (Average)               (None, 26, 32)       0           max_pooling1d[0][0]
#                                                                  max_pooling1d_1[0][0]
#                                                                  max_pooling1d_2[0][0]
#                                                                  max_pooling1d_3[0][0]
#                                                                  max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 24, 32)       3104        average[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 12, 32)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 384)          0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            770         flatten[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 2)         0           dense[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape (TensorFlowOp [(3,)]               0           reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [()]                 0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [()]                 0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims (TensorF [(None, 1, 1, 2)]    0           reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(1,)]               0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat/values_1 (Te [(1,)]               0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_2 (Te [(1,)]               0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Tile (TensorFlowOpL [(None, 1, 5, 2)]    0           tf_op_layer_ExpandDims[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(3,)]               0           tf_op_layer_strided_slice[0][0]
#                                                                  tf_op_layer_concat/values_1[0][0]
#                                                                  tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape (TensorFlow [(None, None, 2)]    0           tf_op_layer_Tile[0][0]
#                                                                  tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# softmax_1 (Softmax)             (None, None, 2)      0           tf_op_layer_Reshape[0][0]
# ==================================================================================================
# Total params: 4,514
# Trainable params: 4,514
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# Total batch: 194171
# Number of null samples: 192008
# Number of non-null samples: 2163
# With thinning factor 0.5 will remove 96004 null samples
# Total batch: 64724
# Number of null samples: 64037
# Number of non-null samples: 687
# With thinning factor 0.5 will remove 32018 null samples
# Epoch 1/5
# 3068/3068 [==============================] - ETA: 0s - loss: 1.3871 - acc: 0.5001 - prc: 0.5008 - precision: 0.0000e+00 - Precision_avg: 3.1991e-04
# [I 2022-05-04 10:46:42,209] Trial 3 pruned. Trial was pruned at epoch 0.
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# bx (InputLayer)                 [(None, 50, 1)]      0
# __________________________________________________________________________________________________
# by (InputLayer)                 [(None, 50, 1)]      0
# __________________________________________________________________________________________________
# bz (InputLayer)                 [(None, 50, 1)]      0
# __________________________________________________________________________________________________
# jy (InputLayer)                 [(None, 50, 1)]      0
# __________________________________________________________________________________________________
# vz (InputLayer)                 [(None, 50, 1)]      0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 48, 16)       64          bx[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 48, 16)       64          by[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 48, 16)       64          bz[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 48, 16)       64          jy[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 48, 16)       64          vz[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 24, 16)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 24, 16)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 24, 16)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 24, 16)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 24, 16)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# average (Average)               (None, 24, 16)       0           max_pooling1d[0][0]
#                                                                  max_pooling1d_1[0][0]
#                                                                  max_pooling1d_2[0][0]
#                                                                  max_pooling1d_3[0][0]
#                                                                  max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 22, 16)       784         average[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 11, 16)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 176)          0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            354         flatten[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 2)         0           dense[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape (TensorFlowOp [(3,)]               0           reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [()]                 0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [()]                 0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims (TensorF [(None, 1, 1, 2)]    0           reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(1,)]               0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat/values_1 (Te [(1,)]               0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_2 (Te [(1,)]               0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Tile (TensorFlowOpL [(None, 1, 4, 2)]    0           tf_op_layer_ExpandDims[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(3,)]               0           tf_op_layer_strided_slice[0][0]
#                                                                  tf_op_layer_concat/values_1[0][0]
#                                                                  tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape (TensorFlow [(None, None, 2)]    0           tf_op_layer_Tile[0][0]
#                                                                  tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# softmax_1 (Softmax)             (None, None, 2)      0           tf_op_layer_Reshape[0][0]
# ==================================================================================================
# Total params: 1,458
# Trainable params: 1,458
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# Total batch: 245234
# Number of null samples: 242569
# Number of non-null samples: 2665
# With thinning factor 0.5 will remove 121284 null samples
# Total batch: 81745
# Number of null samples: 80873
# Number of non-null samples: 872
# With thinning factor 0.5 will remove 40436 null samples
# Epoch 1/5
# 3874/3874 [==============================] - ETA: 0s - loss: 1.1472 - acc: 0.6931 - prc: 0.8312 - precision: 0.0000e+00 - Precision_avg: 0.4992
# [I 2022-05-04 10:51:05,210] Trial 4 pruned. Trial was pruned at epoch 0.
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# bx (InputLayer)                 [(None, 53, 1)]      0
# __________________________________________________________________________________________________
# by (InputLayer)                 [(None, 53, 1)]      0
# __________________________________________________________________________________________________
# bz (InputLayer)                 [(None, 53, 1)]      0
# __________________________________________________________________________________________________
# jy (InputLayer)                 [(None, 53, 1)]      0
# __________________________________________________________________________________________________
# vz (InputLayer)                 [(None, 53, 1)]      0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 51, 32)       128         bx[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 51, 32)       128         by[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 51, 32)       128         bz[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 51, 32)       128         jy[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 51, 32)       128         vz[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 25, 32)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 25, 32)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 25, 32)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 25, 32)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 25, 32)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# average (Average)               (None, 25, 32)       0           max_pooling1d[0][0]
#                                                                  max_pooling1d_1[0][0]
#                                                                  max_pooling1d_2[0][0]
#                                                                  max_pooling1d_3[0][0]
#                                                                  max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 23, 32)       3104        average[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 11, 32)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 352)          0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            706         flatten[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 2)         0           dense[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape (TensorFlowOp [(3,)]               0           reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [()]                 0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [()]                 0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims (TensorF [(None, 1, 1, 2)]    0           reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(1,)]               0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat/values_1 (Te [(1,)]               0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_2 (Te [(1,)]               0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Tile (TensorFlowOpL [(None, 1, 3, 2)]    0           tf_op_layer_ExpandDims[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(3,)]               0           tf_op_layer_strided_slice[0][0]
#                                                                  tf_op_layer_concat/values_1[0][0]
#                                                                  tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape (TensorFlow [(None, None, 2)]    0           tf_op_layer_Tile[0][0]
#                                                                  tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# softmax_1 (Softmax)             (None, None, 2)      0           tf_op_layer_Reshape[0][0]
# ==================================================================================================
# Total params: 4,450
# Trainable params: 4,450
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# Total batch: 324362
# Number of null samples: 320871
# Number of non-null samples: 3491
# With thinning factor 0.5 will remove 160435 null samples
# Total batch: 108121
# Number of null samples: 106989
# Number of non-null samples: 1132
# With thinning factor 0.5 will remove 53494 null samples
# Epoch 1/5
# 5123/5123 [==============================] - ETA: 0s - loss: 16.1185 - acc: 0.9792 - prc: 0.9733 - precision: 0.0000e+00 - Precision_avg: 0.4897
# [I 2022-05-04 10:56:33,380] Trial 5 pruned. Trial was pruned at epoch 0.
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# bx (InputLayer)                 [(None, 23, 1)]      0
# __________________________________________________________________________________________________
# by (InputLayer)                 [(None, 23, 1)]      0
# __________________________________________________________________________________________________
# bz (InputLayer)                 [(None, 23, 1)]      0
# __________________________________________________________________________________________________
# jy (InputLayer)                 [(None, 23, 1)]      0
# __________________________________________________________________________________________________
# vz (InputLayer)                 [(None, 23, 1)]      0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 21, 16)       64          bx[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 21, 16)       64          by[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 21, 16)       64          bz[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 21, 16)       64          jy[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 21, 16)       64          vz[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 10, 16)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 10, 16)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 10, 16)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 10, 16)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 10, 16)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# average (Average)               (None, 10, 16)       0           max_pooling1d[0][0]
#                                                                  max_pooling1d_1[0][0]
#                                                                  max_pooling1d_2[0][0]
#                                                                  max_pooling1d_3[0][0]
#                                                                  max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 8, 16)        784         average[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 4, 16)        0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 64)           0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            130         flatten[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 2)         0           dense[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape (TensorFlowOp [(3,)]               0           reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [()]                 0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [()]                 0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims (TensorF [(None, 1, 1, 2)]    0           reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(1,)]               0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat/values_1 (Te [(1,)]               0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_2 (Te [(1,)]               0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Tile (TensorFlowOpL [(None, 1, 1, 2)]    0           tf_op_layer_ExpandDims[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(3,)]               0           tf_op_layer_strided_slice[0][0]
#                                                                  tf_op_layer_concat/values_1[0][0]
#                                                                  tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape (TensorFlow [(None, None, 2)]    0           tf_op_layer_Tile[0][0]
#                                                                  tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# softmax_1 (Softmax)             (None, None, 2)      0           tf_op_layer_Reshape[0][0]
# ==================================================================================================
# Total params: 1,234
# Trainable params: 1,234
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# Total batch: 1038350
# Number of null samples: 1027933
# Number of non-null samples: 10417
# With thinning factor 0.5 will remove 513966 null samples
# Total batch: 346117
# Number of null samples: 342474
# Number of non-null samples: 3643
# With thinning factor 0.5 will remove 171237 null samples
# Epoch 1/5
# 16387/16387 [==============================] - 775s 47ms/step - loss: 0.8497 - acc: 0.6061 - prc: 0.7632 - precision: 0.0812 - Precision_avg: 0.5417
# Epoch 2/5
#  3138/16387 [====>.........................] - ETA: 10:11 - loss: 0.8254 - acc: 0.6087 - prc: 0.7692 - precision: 0.0831 - Precision_avg: 0.5425
